# %%
import pandas as pd
import numpy
import datetime

# %%
xls = pd.ExcelFile('Manifest data file.xlsx')
df1 = pd.read_excel(xls, 'Stops')
df1.head(5)
# Out:
#   Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0   313325  1.0                     O            112301.0  20220228.0
# 1   313325  2.0                     D            353062.0  20220303.0
# 2  2951839  1.0                     O            353062.0  20220301.0
# 3  2951839  2.0                     D            344073.0  20220302.0
# 4  2952084  1.0                     O            353062.0  20220301.0
#
#    Sch Time  Actual Date  Actual Time
# 0    1903.0   20220301.0       1903.0
# 1     715.0   20220303.0        715.0
# 2     947.0   20220301.0        947.0
# 3    1025.0   20220304.0       1519.0
# 4     947.0   20220301.0        947.0

# %%
df = df1['Sch Date'].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val = str(int(a))
        date_obj = datetime.datetime.strptime(val ,'%Y%m%d')
        val = str(date_obj.date())
        arr.append(val)
    except:
        arr.append("NA")
print(type(arr))
df1['epoch Sch Date'] = arr
df1
# Out:
# <class 'list'>
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date
# 0        1903.0   20220301.0       1903.0     2022-02-28
# 1         715.0   20220303.0        715.0     2022-03-03
# 2         947.0   20220301.0        947.0     2022-03-01
# 3        1025.0   20220304.0       1519.0     2022-03-02
# 4         947.0   20220301.0        947.0     2022-03-01
# ...         ...          ...          ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20
# 73353    1200.0   20220420.0        809.0     2022-04-20
# 73354    1700.0   20220415.0       1700.0     2022-04-15
# 73355    1400.0   20220419.0       1400.0     2022-04-19
# 73356       NaN          NaN          NaN             NA
#
# [73357 rows x 9 columns]

# %%
df = df1['Sch Time'].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val1 = int(a)
        val = int(a)
        val1=int(val1/60)
        while (val1)>24:
            val1 = val1-24    
        h = str(int(val1)).zfill(2)
        m = str(val%60).zfill(2)
        s = "00"
        val2 = h+":"+m+":"+s
        arr.append(val2)
    except:
        arr.append("NA")
df1['epoch Sch Time'] = arr
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
# [73357 rows x 10 columns]

# %%
df = df1[['epoch Sch Date','epoch Sch Time']].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val = str(a)
        val1 = val[2:12]
        val2 = val[15:23]
        val=str(val1+" "+val2+",72")
        dt_obj = datetime.datetime.strptime(val, '%Y-%m-%d %H:%M:%S,%f')  
        epoch_msec = dt_obj.timestamp()*1000
        arr.append(epoch_msec)
    except:
        arr.append("NA")
df1['Epoch Time'] = arr
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time
# 0      1.64601e+12
# 1      1.64629e+12
# 2      1.64613e+12
# 3      1.64622e+12
# 4      1.64613e+12
# ...            ...
# 73352  1.65045e+12
# 73353  1.65047e+12
# 73354  1.64998e+12
# 73355  1.65039e+12
# 73356           NA
#
# [73357 rows x 11 columns]

# %%
df = df1['Actual Date'].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val = str(int(a))
        date_obj = datetime.datetime.strptime(val ,'%Y%m%d')
        val = str(date_obj.date())
        arr.append(val)
    except:
        arr.append("NA")
df1['epoch Actual Date'] = arr
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time epoch Actual Date
# 0      1.64601e+12        2022-03-01
# 1      1.64629e+12        2022-03-03
# 2      1.64613e+12        2022-03-01
# 3      1.64622e+12        2022-03-04
# 4      1.64613e+12        2022-03-01
# ...            ...               ...
# 73352  1.65045e+12        2022-04-20
# 73353  1.65047e+12        2022-04-20
# 73354  1.64998e+12        2022-04-15
# 73355  1.65039e+12        2022-04-19
# 73356           NA                NA
#
# [73357 rows x 12 columns]

# %%
df = df1['Actual Time'].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val1 = int(a)
        val = int(a)
        val1=int(val1/60)
        while (val1)>24:
            val1 = val1-24    
        h = str(int(val1)).zfill(2)
        m = str(val%60).zfill(2)
        s = "00"
        val2 = h+":"+m+":"+s
        arr.append(val2)
    except:
        arr.append("NA")
df1['epoch Actual Time'] = arr
df1
# Out:
# <class 'list'>
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time epoch Actual Date epoch Actual Time
# 0      1.64601e+12        2022-03-01          07:43:00
# 1      1.64629e+12        2022-03-03          11:55:00
# 2      1.64613e+12        2022-03-01          15:47:00
# 3      1.64622e+12        2022-03-04          01:19:00
# 4      1.64613e+12        2022-03-01          15:47:00
# ...            ...               ...               ...
# 73352  1.65045e+12        2022-04-20          15:54:00
# 73353  1.65047e+12        2022-04-20          13:29:00
# 73354  1.64998e+12        2022-04-15          04:20:00
# 73355  1.65039e+12        2022-04-19          23:20:00
# 73356           NA                NA                NA
#
# [73357 rows x 13 columns]

# %%
df = df1['Sch Time'].values
arr = []
arr1=[]
for i in range(len(df)):
    a=df[i]
    try:
        val = int(a)
        val += 120
        arr.append(val)
    except:
        arr.append("NA")
for j in range(len(df)):
    try:
        val1 = arr[j]
        val2=arr[j]
        val2=int(val2/60)
        while (val2)>24:
            val2 = val2-24    
        h1 = str(int(val2)).zfill(2)
        m1 = str(val1%60).zfill(2)
        s1 = "00"
        val3 = h1+":"+m1+":"+s1
        arr1.append(val3)
    except:
        arr1.append("NA") 
df1['Schedule End'] = arr1
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time epoch Actual Date epoch Actual Time Schedule End
# 0      1.64601e+12        2022-03-01          07:43:00     09:43:00
# 1      1.64629e+12        2022-03-03          11:55:00     13:55:00
# 2      1.64613e+12        2022-03-01          15:47:00     17:47:00
# 3      1.64622e+12        2022-03-04          01:19:00     19:05:00
# 4      1.64613e+12        2022-03-01          15:47:00     17:47:00
# ...            ...               ...               ...          ...
# 73352  1.65045e+12        2022-04-20          15:54:00     17:54:00
# 73353  1.65047e+12        2022-04-20          13:29:00     22:00:00
# 73354  1.64998e+12        2022-04-15          04:20:00     06:20:00
# 73355  1.65039e+12        2022-04-19          23:20:00     01:20:00
# 73356           NA                NA                NA           NA
#
# [73357 rows x 14 columns]

# %%
df = df1['Actual Time'].values
arr = []
arr1=[]
for i in range(len(df)):
    a=df[i]
    try:
        val = int(a)
        val += 120
        arr.append(val)
    except:
        arr.append("NA")
for j in range(len(df)):
    try:
        val1 = arr[j]
        val2=arr[j]
        val2=val2/60
        while (val2)>24:
            val2 = val2-24    
        h1 = str(int(val2)).zfill(2)
        m1 = str(val1%60).zfill(2)
        s1 = "00"
        val1 = h1+":"+m1+":"+s1
        arr1.append(val1)
    except:
        arr1.append("NA") 
df1['Actual End'] = arr1
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time epoch Actual Date epoch Actual Time Schedule End Actual End
# 0      1.64601e+12        2022-03-01          07:43:00     09:43:00   09:43:00
# 1      1.64629e+12        2022-03-03          11:55:00     13:55:00   13:55:00
# 2      1.64613e+12        2022-03-01          15:47:00     17:47:00   17:47:00
# 3      1.64622e+12        2022-03-04          01:19:00     19:05:00   03:19:00
# 4      1.64613e+12        2022-03-01          15:47:00     17:47:00   17:47:00
# ...            ...               ...               ...          ...        ...
# 73352  1.65045e+12        2022-04-20          15:54:00     17:54:00   17:54:00
# 73353  1.65047e+12        2022-04-20          13:29:00     22:00:00   15:29:00
# 73354  1.64998e+12        2022-04-15          04:20:00     06:20:00   06:20:00
# 73355  1.65039e+12        2022-04-19          23:20:00     01:20:00   01:20:00
# 73356           NA                NA                NA           NA         NA
#
# [73357 rows x 15 columns]

# %%
df = df1[['Epoch Time']].values
arr = []
for i in range(len(df)):
    a=df[i]
    try:
        val = int(a)+7200
        arr.append(str(val))
    except:
        arr.append("NA")
df1['Actual Epoch Time'] = arr
df1
# Out:
#         Manifest  Seq O=Origin,D=Final Stop  Stop Location Code    Sch Date  \
# 0         313325  1.0                     O            112301.0  20220228.0
# 1         313325  2.0                     D            353062.0  20220303.0
# 2        2951839  1.0                     O            353062.0  20220301.0
# 3        2951839  2.0                     D            344073.0  20220302.0
# 4        2952084  1.0                     O            353062.0  20220301.0
# ...          ...  ...                   ...                 ...         ...
# 73352  106481155  1.0                     O            313267.0  20220420.0
# 73353  106481155  2.0                     D            302742.0  20220420.0
# 73354  106481213  1.0                     O            142375.0  20220415.0
# 73355  106481213  2.0                     D            101392.0  20220419.0
# 73356            NaN                   NaN                 NaN         NaN
#
#        Sch Time  Actual Date  Actual Time epoch Sch Date epoch Sch Time  \
# 0        1903.0   20220301.0       1903.0     2022-02-28       07:43:00
# 1         715.0   20220303.0        715.0     2022-03-03       11:55:00
# 2         947.0   20220301.0        947.0     2022-03-01       15:47:00
# 3        1025.0   20220304.0       1519.0     2022-03-02       17:05:00
# 4         947.0   20220301.0        947.0     2022-03-01       15:47:00
# ...         ...          ...          ...            ...            ...
# 73352     954.0   20220420.0        954.0     2022-04-20       15:54:00
# 73353    1200.0   20220420.0        809.0     2022-04-20       20:00:00
# 73354    1700.0   20220415.0       1700.0     2022-04-15       04:20:00
# 73355    1400.0   20220419.0       1400.0     2022-04-19       23:20:00
# 73356       NaN          NaN          NaN             NA             NA
#
#         Epoch Time epoch Actual Date epoch Actual Time Schedule End  \
# 0      1.64601e+12        2022-03-01          07:43:00     09:43:00
# 1      1.64629e+12        2022-03-03          11:55:00     13:55:00
# 2      1.64613e+12        2022-03-01          15:47:00     17:47:00
# 3      1.64622e+12        2022-03-04          01:19:00     19:05:00
# 4      1.64613e+12        2022-03-01          15:47:00     17:47:00
# ...            ...               ...               ...          ...
# 73352  1.65045e+12        2022-04-20          15:54:00     17:54:00
# 73353  1.65047e+12        2022-04-20          13:29:00     22:00:00
# 73354  1.64998e+12        2022-04-15          04:20:00     06:20:00
# 73355  1.65039e+12        2022-04-19          23:20:00     01:20:00
# 73356           NA                NA                NA           NA
#
#       Actual End Actual Epoch Time
# 0       09:43:00     1646014387920
# 1       13:55:00     1646288707920
# 2       17:47:00     1646129827920
# 3       03:19:00     1646220907920
# 4       17:47:00     1646129827920
# ...          ...               ...
# 73352   17:54:00     1650450247920
# 73353   15:29:00     1650465007920
# 73354   06:20:00     1649976607920
# 73355   01:20:00     1650390607920
# 73356         NA                NA
#
# [73357 rows x 16 columns]
